# %%
from utils.helpers import load_env_file

# %%
import os

# %%
load_env_file()
# Out:
# WindowsPath('C:/Users/yzalm/Projetos/akira_sales/.env')

# %%
a = os.getenv('AZURE_CLIENT_ID')

# %%
a
# Out:
# '9706a4d1-7d0a-48db-87d0-d7bf4792dde2'
