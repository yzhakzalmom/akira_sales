# %% [markdown]
# # Tratamento da planilha de vendas

# %%
import xlwings as xw

# %%
# Inicializa app xlwings
app = xw.App(visible=False, add_book=False)

# %%
# Lê o book de vendas
vendas_wb = app.books.open('../data/bronze/sales/2025_11.xlsx')

# Lê a planilha de vendas
vendas_ws = vendas_wb.sheets[0]

# %%
# Remove as linhas inciais, que impedem a leitura correta
vendas_ws[0:4, 0:1000].delete()

# %%
# Altera nome das colunas adicionando seu cabeçalho
for col in range(0, vendas_ws[1, 0].end('right').column):

    # Substitui espaços por underline
    vendas_ws[1, col].value = vendas_ws[1, col].value.replace(' ', '_')

    # Adiciona o cabeçalho à coluna
    vendas_ws[1, col].value += f'_{vendas_ws[0, vendas_ws[0, col + 1].end('left').column - 1].value}'

# %%
# Exclui os cabeçalhos
vendas_ws[0, 0:1000].delete()

# %%
# Salva a planilha
vendas_wb.save('../data/silver/separate_sales/2025_11_treated.xlsx')
vendas_wb.close()
app.quit()
