# %% [markdown]
# Change root to src/, so that it is accessible from notebooks

# %%
import sys
from pathlib import Path

# %%
project_root = Path('/Workspace/Users/zalmom_admin@yzalmomoutlook.onmicrosoft.com/akira_sales')
sys.path.append(str(project_root / "src"))
